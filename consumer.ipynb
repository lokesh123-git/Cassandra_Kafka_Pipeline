# %%
from confluent_kafka import DeserializingConsumer, KafkaError
from confluent_kafka.schema_registry import SchemaRegistryClient
from confluent_kafka.schema_registry.avro import AvroDeserializer
from confluent_kafka.serialization import StringDeserializer
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
from datetime import datetime
import uuid
from cassandra import ConsistencyLevel

# Cassandra connection
cloud_config= {
  'secure_connect_bundle': 'secure-connect-kafka-cassandra.zip'
}
auth_provider = PlainTextAuthProvider('fwYCYuKfTnzdISZebSFsRUpH', 'Ze,I-gql5chyu_Umc00iwwf_UTU_ktjq0W1NXjTU.e+1d6vT1tI16dw8KQ9J+TAgtv6_GC3eNJoxTccRCE_BgLE-7ieErS0FAZGsLBL1pj.BintLJqZC5D_o68lso3KB')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

# Define Kafka configuration
kafka_config = {
    'bootstrap.servers': 'pkc-6ojv2.us-west4.gcp.confluent.cloud:9092',
    'sasl.mechanisms': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': 'KE3YCSOIN46EIKLM',
    'sasl.password': 'DfHmXuw2vR38KYDSbvXyGBNZCxsZrFF+VtTTPoeZMgp33o/oV8l7s0ObJ/Q48HmK',
    'group.id': 'group16',
    'auto.offset.reset': 'earliest'
}

# Create a Schema Registry client
schema_registry_client = SchemaRegistryClient({
  'url': 'https://psrc-zj6ny.us-east-2.aws.confluent.cloud',
  'basic.auth.user.info': '{}:{}'.format('NJHM72JKLO43DSHW', '3jAGYLSdojChjA9uv3fuaV/dS7D29l7tcZYcEVmDQqD0IeXeyCpNOXa7lTZb4hpy')
})

# Fetch the latest Avro schema for the value
subject_name = 'olist_orders_dataset-value'
schema_str = schema_registry_client.get_latest_version(subject_name).schema.schema_str

# Create Avro Deserializer for the value
key_deserializer = StringDeserializer('utf_8')
avro_deserializer = AvroDeserializer(schema_registry_client, schema_str)

# Define the DeserializingConsumer
consumer = DeserializingConsumer({
    'bootstrap.servers': kafka_config['bootstrap.servers'],
    'security.protocol': kafka_config['security.protocol'],
    'sasl.mechanisms': kafka_config['sasl.mechanisms'],
    'sasl.username': kafka_config['sasl.username'],
    'sasl.password': kafka_config['sasl.password'],
    'key.deserializer': key_deserializer,
    'value.deserializer': avro_deserializer,
    'group.id': kafka_config['group.id'],
    'auto.offset.reset': kafka_config['auto.offset.reset'],
    # 'enable.auto.commit': True,
    # 'auto.commit.interval.ms': 5000 # Commit every 5000 ms, i.e., every 5 seconds
})

# Subscribe to the 'retail_data' topic
consumer.subscribe(['olist_orders_dataset'])

def process_message(message):
    # Process the Kafka message and derive the new columns
    key = message.key()  
    value = message.value()
    
    # Convert 'order_purchase_timestamp' string to datetime object
    order_purchase_timestamp_str = value['order_purchase_timestamp']
    order_purchase_timestamp = None
    if order_purchase_timestamp_str is not None:
        order_purchase_timestamp = datetime.strptime(order_purchase_timestamp_str, '%Y-%m-%d %H:%M:%S')
    
    # Convert 'order_approved_at' to a datetime object
    order_approved_at_str = value['order_approved_at']
    order_approved_at = None
    if order_approved_at_str is not None:
        order_approved_at = datetime.strptime(order_approved_at_str, "%Y-%m-%d %H:%M:%S")
    
    # Convert 'order_delivered_carrier_date' to a datetime object
    order_delivered_carrier_date_str = value['order_delivered_carrier_date']
    order_delivered_carrier_date = None
    if order_delivered_carrier_date_str is not None:
        order_delivered_carrier_date = datetime.strptime(order_delivered_carrier_date_str, "%Y-%m-%d %H:%M:%S")
    
    # Convert 'order_delivered_customer_date' to a datetime object
    order_delivered_customer_date_str = value['order_delivered_customer_date']
    order_delivered_customer_date = None
    if order_delivered_customer_date_str is not None:
        order_delivered_customer_date = datetime.strptime(order_delivered_customer_date_str, "%Y-%m-%d %H:%M:%S")
    
    # Convert 'order_estimated_delivery_date' to a datetime object
    order_estimated_delivery_date_str = value['order_estimated_delivery_date']
    order_estimated_delivery_date = None
    if order_estimated_delivery_date_str is not None:
        order_estimated_delivery_date = datetime.strptime(order_estimated_delivery_date_str, "%Y-%m-%d %H:%M:%S")
    
    purchase_hour = order_purchase_timestamp.hour
    purchase_day_of_week = order_purchase_timestamp.strftime('%A')
    
    # Convert 'order_id' to a valid UUID format
    try:
        order_id = uuid.UUID(value['order_id'])
    except ValueError:
        # If the 'order_id' is not a valid UUID, handle the error or skip the message
        print(f"Invalid 'order_id': {value['order_id']}")
        return
    
    # Convert 'customer_id' to a valid UUID format
    try:
        customer_id = uuid.UUID(value['customer_id'])
    except ValueError:
        # If the 'order_id' is not a valid UUID, handle the error or skip the message
        print(f"Invalid 'customer_id': {value['customer_id']}")
        return

    try:
        # Ingest the transformed data into the 'orders' table in Cassandra
        query = "INSERT INTO ecommerce.orders (order_id, customer_id, order_status, order_purchase_timestamp, " \
                "order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, " \
                "order_estimated_delivery_date, order_hour, Oorder_day_of_week) " \
                "VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"
                
        prepared = session.prepare(query)
        
        bound_statement = prepared.bind((
        order_id,
        customer_id,
        value['order_status'],
        order_purchase_timestamp,
        order_approved_at,
        order_delivered_carrier_date,
        order_delivered_customer_date,
        order_estimated_delivery_date,
        purchase_hour,
        purchase_day_of_week
    ))
        
        bound_statement.consistency_level = ConsistencyLevel.QUORUM
        
        session.execute(bound_statement)
        
        print(f'Record {key} inserted successfully !!')
        
        # Manually commit the offset to Kafka
        consumer.commit(message)
        
    except Exception as err:
        
        print(f"Exception occured while inserting {key} into the table: {err}")
    

# Continually read messages from Kafka
try:
    while True:
        msg = consumer.poll(1.0)

        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KafkaError._PARTITION_EOF:
                # End of partition event, not an error
                print('Reached end of partition')
            else:
                print('Error while consuming: {}'.format(msg.error()))
        else:
            print('Successfully consumed record with key {} and value {}'.format(msg.key(), msg.value()))
            process_message(msg)

except KeyboardInterrupt:
    pass

finally:
    consumer.close()
    cluster.shutdown()
# Out:
# Successfully consumed record with key b0830fb4747a6c6d20dea0b8c802d7ef_53cdb2fc8bc7dce0b6741e2150273451 and value {'order_id': '53cdb2fc8bc7dce0b6741e2150273451', 'customer_id': 'b0830fb4747a6c6d20dea0b8c802d7ef', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-07-24 20:41:37', 'order_approved_at': '2018-07-26 03:24:27', 'order_delivered_carrier_date': '2018-07-26 14:31:00', 'order_delivered_customer_date': '2018-08-07 15:27:45', 'order_estimated_delivery_date': '2018-08-13 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record b0830fb4747a6c6d20dea0b8c802d7ef_53cdb2fc8bc7dce0b6741e2150273451 inserted successfully !!
# Successfully consumed record with key f88197465ea7920adcdbec7375364d82_949d5b44dbf5de918fe9c16f97b45f8a and value {'order_id': '949d5b44dbf5de918fe9c16f97b45f8a', 'customer_id': 'f88197465ea7920adcdbec7375364d82', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-11-18 19:28:06', 'order_approved_at': '2017-11-18 19:45:59', 'order_delivered_carrier_date': '2017-11-22 13:39:59', 'order_delivered_customer_date': '2017-12-02 00:28:42', 'order_estimated_delivery_date': '2017-12-15 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record f88197465ea7920adcdbec7375364d82_949d5b44dbf5de918fe9c16f97b45f8a inserted successfully !!
# Successfully consumed record with key 9bdf08b4b3b52b5526ff42d37d47f222_6514b8ad8028c9f2cc2374ded245783f and value {'order_id': '6514b8ad8028c9f2cc2374ded245783f', 'customer_id': '9bdf08b4b3b52b5526ff42d37d47f222', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-05-16 13:10:30', 'order_approved_at': '2017-05-16 13:22:11', 'order_delivered_carrier_date': '2017-05-22 10:07:46', 'order_delivered_customer_date': '2017-05-26 12:55:51', 'order_estimated_delivery_date': '2017-06-07 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 9bdf08b4b3b52b5526ff42d37d47f222_6514b8ad8028c9f2cc2374ded245783f inserted successfully !!
# Successfully consumed record with key f54a9f0e6b351c431402b8461ea51999_76c6e866289321a7c93b82b54852dc33 and value {'order_id': '76c6e866289321a7c93b82b54852dc33', 'customer_id': 'f54a9f0e6b351c431402b8461ea51999', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-01-23 18:29:09', 'order_approved_at': '2017-01-25 02:50:47', 'order_delivered_carrier_date': '2017-01-26 14:16:31', 'order_delivered_customer_date': '2017-02-02 14:08:10', 'order_estimated_delivery_date': '2017-03-06 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record f54a9f0e6b351c431402b8461ea51999_76c6e866289321a7c93b82b54852dc33 inserted successfully !!
# Successfully consumed record with key 494dded5b201313c64ed7f100595b95c_e6ce16cb79ec1d90b1da9085a6118aeb and value {'order_id': 'e6ce16cb79ec1d90b1da9085a6118aeb', 'customer_id': '494dded5b201313c64ed7f100595b95c', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-05-16 19:41:10', 'order_approved_at': '2017-05-16 19:50:18', 'order_delivered_carrier_date': '2017-05-18 11:40:40', 'order_delivered_customer_date': '2017-05-29 11:18:31', 'order_estimated_delivery_date': '2017-06-07 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 494dded5b201313c64ed7f100595b95c_e6ce16cb79ec1d90b1da9085a6118aeb inserted successfully !!
# Successfully consumed record with key 7711cf624183d843aafe81855097bc37_34513ce0c4fab462a55830c0989c7edb and value {'order_id': '34513ce0c4fab462a55830c0989c7edb', 'customer_id': '7711cf624183d843aafe81855097bc37', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-07-13 19:58:11', 'order_approved_at': '2017-07-13 20:10:08', 'order_delivered_carrier_date': '2017-07-14 18:43:29', 'order_delivered_customer_date': '2017-07-19 14:04:48', 'order_estimated_delivery_date': '2017-08-08 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 7711cf624183d843aafe81855097bc37_34513ce0c4fab462a55830c0989c7edb inserted successfully !!
# Successfully consumed record with key d3e3b74c766bc6214e0c830b17ee2341_82566a660a982b15fb86e904c8d32918 and value {'order_id': '82566a660a982b15fb86e904c8d32918', 'customer_id': 'd3e3b74c766bc6214e0c830b17ee2341', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-06-07 10:06:19', 'order_approved_at': '2018-06-09 03:13:12', 'order_delivered_carrier_date': '2018-06-11 13:29:00', 'order_delivered_customer_date': '2018-06-19 12:05:52', 'order_estimated_delivery_date': '2018-07-18 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record d3e3b74c766bc6214e0c830b17ee2341_82566a660a982b15fb86e904c8d32918 inserted successfully !!
# Successfully consumed record with key 19402a48fe860416adf93348aba37740_5ff96c15d0b717ac6ad1f3d77225a350 and value {'order_id': '5ff96c15d0b717ac6ad1f3d77225a350', 'customer_id': '19402a48fe860416adf93348aba37740', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-07-25 17:44:10', 'order_approved_at': '2018-07-25 17:55:14', 'order_delivered_carrier_date': '2018-07-26 13:16:00', 'order_delivered_customer_date': '2018-07-30 15:52:25', 'order_estimated_delivery_date': '2018-08-08 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 19402a48fe860416adf93348aba37740_5ff96c15d0b717ac6ad1f3d77225a350 inserted successfully !!
# Successfully consumed record with key 3df704f53d3f1d4818840b34ec672a9f_432aaf21d85167c2c86ec9448c4e42cc and value {'order_id': '432aaf21d85167c2c86ec9448c4e42cc', 'customer_id': '3df704f53d3f1d4818840b34ec672a9f', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-03-01 14:14:28', 'order_approved_at': '2018-03-01 15:10:47', 'order_delivered_carrier_date': '2018-03-02 21:09:20', 'order_delivered_customer_date': '2018-03-12 23:36:26', 'order_estimated_delivery_date': '2018-03-21 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 3df704f53d3f1d4818840b34ec672a9f_432aaf21d85167c2c86ec9448c4e42cc inserted successfully !!
# Successfully consumed record with key 3187789bec990987628d7a9beb4dd6ac_116f0b09343b49556bbad5f35bee0cdf and value {'order_id': '116f0b09343b49556bbad5f35bee0cdf', 'customer_id': '3187789bec990987628d7a9beb4dd6ac', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-12-26 23:41:31', 'order_approved_at': '2017-12-26 23:50:22', 'order_delivered_carrier_date': '2017-12-28 18:33:05', 'order_delivered_customer_date': '2018-01-08 22:36:36', 'order_estimated_delivery_date': '2018-01-29 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 3187789bec990987628d7a9beb4dd6ac_116f0b09343b49556bbad5f35bee0cdf inserted successfully !!
# Successfully consumed record with key 7f8c8b9c2ae27bf3300f670c3d478be8_83018ec114eee8641c97e08f7b4e926f and value {'order_id': '83018ec114eee8641c97e08f7b4e926f', 'customer_id': '7f8c8b9c2ae27bf3300f670c3d478be8', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-10-26 15:54:26', 'order_approved_at': '2017-10-26 16:08:14', 'order_delivered_carrier_date': '2017-10-26 21:46:53', 'order_delivered_customer_date': '2017-11-08 22:22:00', 'order_estimated_delivery_date': '2017-11-23 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 7f8c8b9c2ae27bf3300f670c3d478be8_83018ec114eee8641c97e08f7b4e926f inserted successfully !!
# Successfully consumed record with key 72ae281627a6102d9b3718528b420f8a_2807d0e504d6d4894d41672727bc139f and value {'order_id': '2807d0e504d6d4894d41672727bc139f', 'customer_id': '72ae281627a6102d9b3718528b420f8a', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-02-03 20:37:35', 'order_approved_at': '2018-02-03 20:50:22', 'order_delivered_carrier_date': '2018-02-05 22:37:28', 'order_delivered_customer_date': '2018-02-08 16:13:46', 'order_estimated_delivery_date': '2018-02-21 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 72ae281627a6102d9b3718528b420f8a_2807d0e504d6d4894d41672727bc139f inserted successfully !!
# Successfully consumed record with key 7e20bf5ca92da68200643bda76c504c6_acce194856392f074dbf9dada14d8d82 and value {'order_id': 'acce194856392f074dbf9dada14d8d82', 'customer_id': '7e20bf5ca92da68200643bda76c504c6', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-06-04 00:00:13', 'order_approved_at': '2018-06-05 00:35:10', 'order_delivered_carrier_date': '2018-06-05 13:24:00', 'order_delivered_customer_date': '2018-06-16 15:20:55', 'order_estimated_delivery_date': '2018-07-18 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 7e20bf5ca92da68200643bda76c504c6_acce194856392f074dbf9dada14d8d82 inserted successfully !!
# Successfully consumed record with key 8b212b9525f9e74e85e37ed6df37693e_dd78f560c270f1909639c11b925620ea and value {'order_id': 'dd78f560c270f1909639c11b925620ea', 'customer_id': '8b212b9525f9e74e85e37ed6df37693e', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-03-12 01:50:26', 'order_approved_at': '2018-03-12 03:28:34', 'order_delivered_carrier_date': '2018-03-12 21:06:37', 'order_delivered_customer_date': '2018-03-21 14:41:50', 'order_estimated_delivery_date': '2018-03-28 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 8b212b9525f9e74e85e37ed6df37693e_dd78f560c270f1909639c11b925620ea inserted successfully !!
# Successfully consumed record with key cce89a605105b148387c52e286ac8335_91b2a010e1e45e6ba3d133fa997597be and value {'order_id': '91b2a010e1e45e6ba3d133fa997597be', 'customer_id': 'cce89a605105b148387c52e286ac8335', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-05-02 11:45:38', 'order_approved_at': '2018-05-03 12:55:01', 'order_delivered_carrier_date': '2018-05-10 16:16:00', 'order_delivered_customer_date': '2018-05-16 20:56:24', 'order_estimated_delivery_date': '2018-05-23 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record cce89a605105b148387c52e286ac8335_91b2a010e1e45e6ba3d133fa997597be inserted successfully !!
# Successfully consumed record with key 52142aa69d8d0e1247ab0cada0f76023_1790eea0b567cf50911c057cf20f90f9 and value {'order_id': '1790eea0b567cf50911c057cf20f90f9', 'customer_id': '52142aa69d8d0e1247ab0cada0f76023', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-04-16 21:15:39', 'order_approved_at': '2018-04-16 22:10:26', 'order_delivered_carrier_date': '2018-04-18 13:05:09', 'order_delivered_customer_date': '2018-05-05 12:28:34', 'order_estimated_delivery_date': '2018-05-15 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 52142aa69d8d0e1247ab0cada0f76023_1790eea0b567cf50911c057cf20f90f9 inserted successfully !!
# Successfully consumed record with key d9ef95f98d8da3b492bb8c0447910498_d887b52c6516beb39e8cd44a5f8b60f7 and value {'order_id': 'd887b52c6516beb39e8cd44a5f8b60f7', 'customer_id': 'd9ef95f98d8da3b492bb8c0447910498', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-02-03 12:38:58', 'order_approved_at': '2018-02-03 12:50:30', 'order_delivered_carrier_date': '2018-02-05 21:26:53', 'order_delivered_customer_date': '2018-02-22 00:07:55', 'order_estimated_delivery_date': '2018-03-07 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record d9ef95f98d8da3b492bb8c0447910498_d887b52c6516beb39e8cd44a5f8b60f7 inserted successfully !!
# Successfully consumed record with key 5f16605299d698660e0606f7eae2d2f9_8563039e855156e48fccee4d611a3196 and value {'order_id': '8563039e855156e48fccee4d611a3196', 'customer_id': '5f16605299d698660e0606f7eae2d2f9', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-02-17 15:59:46', 'order_approved_at': '2018-02-17 16:15:34', 'order_delivered_carrier_date': '2018-02-20 23:03:56', 'order_delivered_customer_date': '2018-03-20 00:59:25', 'order_estimated_delivery_date': '2018-03-20 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 5f16605299d698660e0606f7eae2d2f9_8563039e855156e48fccee4d611a3196 inserted successfully !!
# Successfully consumed record with key 295ae9b35379e077273387ff64354b6f_5acce57f8d9dfd55fa48e212a641a69d and value {'order_id': '5acce57f8d9dfd55fa48e212a641a69d', 'customer_id': '295ae9b35379e077273387ff64354b6f', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-07-31 21:37:10', 'order_approved_at': '2017-08-02 02:56:02', 'order_delivered_carrier_date': '2017-08-03 18:32:48', 'order_delivered_customer_date': '2017-08-08 21:24:41', 'order_estimated_delivery_date': '2017-08-22 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 295ae9b35379e077273387ff64354b6f_5acce57f8d9dfd55fa48e212a641a69d inserted successfully !!
# Successfully consumed record with key 2a1dfb647f32f4390e7b857c67458536_434d158e96bdd6972ad6e6d73ddcfd22 and value {'order_id': '434d158e96bdd6972ad6e6d73ddcfd22', 'customer_id': '2a1dfb647f32f4390e7b857c67458536', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-06-01 12:23:13', 'order_approved_at': '2018-06-05 03:35:15', 'order_delivered_carrier_date': '2018-06-08 11:49:00', 'order_delivered_customer_date': '2018-06-18 21:32:52', 'order_estimated_delivery_date': '2018-07-17 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 2a1dfb647f32f4390e7b857c67458536_434d158e96bdd6972ad6e6d73ddcfd22 inserted successfully !!
# Successfully consumed record with key 8644be24d48806bc3a88fd59fb47ceb1_948097deef559c742e7ce321e5e58919 and value {'order_id': '948097deef559c742e7ce321e5e58919', 'customer_id': '8644be24d48806bc3a88fd59fb47ceb1', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-08-04 17:10:39', 'order_approved_at': '2017-08-04 17:25:11', 'order_delivered_carrier_date': '2017-08-07 17:52:01', 'order_delivered_customer_date': '2017-08-12 14:08:40', 'order_estimated_delivery_date': '2017-09-01 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 8644be24d48806bc3a88fd59fb47ceb1_948097deef559c742e7ce321e5e58919 inserted successfully !!
# Successfully consumed record with key caded193e8e47b8362864762a83db3c5_ee64d42b8cf066f35eac1cf57de1aa85 and value {'order_id': 'ee64d42b8cf066f35eac1cf57de1aa85', 'customer_id': 'caded193e8e47b8362864762a83db3c5', 'order_status': 'shipped', 'order_purchase_timestamp': '2018-06-04 16:44:48', 'order_approved_at': '2018-06-05 04:31:18', 'order_delivered_carrier_date': '2018-06-05 14:32:00', 'order_delivered_customer_date': None, 'order_estimated_delivery_date': '2018-06-28 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record caded193e8e47b8362864762a83db3c5_ee64d42b8cf066f35eac1cf57de1aa85 inserted successfully !!
# Successfully consumed record with key 4f28355e5c17a4a42d3ce2439a1d4501_6ebaec694d7025e2ad4a05dba887c032 and value {'order_id': '6ebaec694d7025e2ad4a05dba887c032', 'customer_id': '4f28355e5c17a4a42d3ce2439a1d4501', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-05-18 13:55:47', 'order_approved_at': '2017-05-18 14:05:17', 'order_delivered_carrier_date': '2017-05-19 12:01:38', 'order_delivered_customer_date': '2017-05-29 12:47:20', 'order_estimated_delivery_date': '2017-06-09 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 4f28355e5c17a4a42d3ce2439a1d4501_6ebaec694d7025e2ad4a05dba887c032 inserted successfully !!
# Successfully consumed record with key 569cf68214806a39acc0f39344aea67f_d17dc4a904426827ca80f2ccb3a6be56 and value {'order_id': 'd17dc4a904426827ca80f2ccb3a6be56', 'customer_id': '569cf68214806a39acc0f39344aea67f', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-05-14 20:28:25', 'order_approved_at': '2017-05-14 20:42:45', 'order_delivered_carrier_date': '2017-05-16 08:17:46', 'order_delivered_customer_date': '2017-05-25 09:14:31', 'order_estimated_delivery_date': '2017-06-12 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 569cf68214806a39acc0f39344aea67f_d17dc4a904426827ca80f2ccb3a6be56 inserted successfully !!
# Successfully consumed record with key 2b56e94c2f66f2d97cfa63356f69cee8_5820a1100976432c7968a52da59e9364 and value {'order_id': '5820a1100976432c7968a52da59e9364', 'customer_id': '2b56e94c2f66f2d97cfa63356f69cee8', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-07-29 11:24:17', 'order_approved_at': '2018-07-29 11:44:19', 'order_delivered_carrier_date': '2018-07-30 13:47:00', 'order_delivered_customer_date': '2018-08-02 22:09:11', 'order_estimated_delivery_date': '2018-08-13 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 2b56e94c2f66f2d97cfa63356f69cee8_5820a1100976432c7968a52da59e9364 inserted successfully !!
# Successfully consumed record with key 9ef432eb6251297304e76186b10a928d_e481f51cbdc54678b7cc49136f2d6af7 and value {'order_id': 'e481f51cbdc54678b7cc49136f2d6af7', 'customer_id': '9ef432eb6251297304e76186b10a928d', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-10-02 10:56:33', 'order_approved_at': '2017-10-02 11:07:15', 'order_delivered_carrier_date': '2017-10-04 19:55:00', 'order_delivered_customer_date': '2017-10-10 21:25:13', 'order_estimated_delivery_date': '2017-10-18 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 9ef432eb6251297304e76186b10a928d_e481f51cbdc54678b7cc49136f2d6af7 inserted successfully !!
# Successfully consumed record with key 41ce2a54c0b03bf3443c3d931a367089_47770eb9100c2d0c44946d9cf07ec65d and value {'order_id': '47770eb9100c2d0c44946d9cf07ec65d', 'customer_id': '41ce2a54c0b03bf3443c3d931a367089', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-08-08 08:38:49', 'order_approved_at': '2018-08-08 08:55:23', 'order_delivered_carrier_date': '2018-08-08 13:50:00', 'order_delivered_customer_date': '2018-08-17 18:06:29', 'order_estimated_delivery_date': '2018-09-04 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 41ce2a54c0b03bf3443c3d931a367089_47770eb9100c2d0c44946d9cf07ec65d inserted successfully !!
# Successfully consumed record with key 8ab97904e6daea8866dbdbc4fb7aad2c_ad21c59c0840e6cb83a9ceb5573f8159 and value {'order_id': 'ad21c59c0840e6cb83a9ceb5573f8159', 'customer_id': '8ab97904e6daea8866dbdbc4fb7aad2c', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-02-13 21:18:39', 'order_approved_at': '2018-02-13 22:20:29', 'order_delivered_carrier_date': '2018-02-14 19:46:34', 'order_delivered_customer_date': '2018-02-16 18:17:02', 'order_estimated_delivery_date': '2018-02-26 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 8ab97904e6daea8866dbdbc4fb7aad2c_ad21c59c0840e6cb83a9ceb5573f8159 inserted successfully !!
# Successfully consumed record with key 503740e9ca751ccdda7ba28e9ab8f608_a4591c265e18cb1dcee52889e2d8acc3 and value {'order_id': 'a4591c265e18cb1dcee52889e2d8acc3', 'customer_id': '503740e9ca751ccdda7ba28e9ab8f608', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-07-09 21:57:05', 'order_approved_at': '2017-07-09 22:10:13', 'order_delivered_carrier_date': '2017-07-11 14:58:04', 'order_delivered_customer_date': '2017-07-26 10:57:55', 'order_estimated_delivery_date': '2017-08-01 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 503740e9ca751ccdda7ba28e9ab8f608_a4591c265e18cb1dcee52889e2d8acc3 inserted successfully !!
# Successfully consumed record with key ed0271e0b7da060a393796590e7b737a_136cce7faa42fdb2cefd53fdc79a6098 and value {'order_id': '136cce7faa42fdb2cefd53fdc79a6098', 'customer_id': 'ed0271e0b7da060a393796590e7b737a', 'order_status': 'invoiced', 'order_purchase_timestamp': '2017-04-11 12:22:08', 'order_approved_at': '2017-04-13 13:25:17', 'order_delivered_carrier_date': None, 'order_delivered_customer_date': None, 'order_estimated_delivery_date': '2017-05-09 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record ed0271e0b7da060a393796590e7b737a_136cce7faa42fdb2cefd53fdc79a6098 inserted successfully !!
# Successfully consumed record with key 31ad1d1b63eb9962463f764d4e6e0c9d_e69bfb5eb88e0ed6a785585b27e16dbf and value {'order_id': 'e69bfb5eb88e0ed6a785585b27e16dbf', 'customer_id': '31ad1d1b63eb9962463f764d4e6e0c9d', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-07-29 11:55:02', 'order_approved_at': '2017-07-29 12:05:32', 'order_delivered_carrier_date': '2017-08-10 19:45:24', 'order_delivered_customer_date': '2017-08-16 17:14:30', 'order_estimated_delivery_date': '2017-08-23 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 31ad1d1b63eb9962463f764d4e6e0c9d_e69bfb5eb88e0ed6a785585b27e16dbf inserted successfully !!
# Successfully consumed record with key 3b6828a50ffe546942b7a473d70ac0fc_dcb36b511fcac050b97cd5c05de84dc3 and value {'order_id': 'dcb36b511fcac050b97cd5c05de84dc3', 'customer_id': '3b6828a50ffe546942b7a473d70ac0fc', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-06-07 19:03:12', 'order_approved_at': '2018-06-12 23:31:02', 'order_delivered_carrier_date': '2018-06-11 14:54:00', 'order_delivered_customer_date': '2018-06-21 15:34:32', 'order_estimated_delivery_date': '2018-07-04 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 3b6828a50ffe546942b7a473d70ac0fc_dcb36b511fcac050b97cd5c05de84dc3 inserted successfully !!
# Successfully consumed record with key 738b086814c6fcc74b8cc583f8516ee3_403b97836b0c04a622354cf531062e5f and value {'order_id': '403b97836b0c04a622354cf531062e5f', 'customer_id': '738b086814c6fcc74b8cc583f8516ee3', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-01-02 19:00:43', 'order_approved_at': '2018-01-02 19:09:04', 'order_delivered_carrier_date': '2018-01-03 18:19:09', 'order_delivered_customer_date': '2018-01-20 01:38:59', 'order_estimated_delivery_date': '2018-02-06 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 738b086814c6fcc74b8cc583f8516ee3_403b97836b0c04a622354cf531062e5f inserted successfully !!
# Successfully consumed record with key 059f7fc5719c7da6cbafe370971a8d70_85ce859fd6dc634de8d2f1e290444043 and value {'order_id': '85ce859fd6dc634de8d2f1e290444043', 'customer_id': '059f7fc5719c7da6cbafe370971a8d70', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-11-21 00:03:41', 'order_approved_at': '2017-11-21 00:14:22', 'order_delivered_carrier_date': '2017-11-23 21:32:26', 'order_delivered_customer_date': '2017-11-27 18:28:00', 'order_estimated_delivery_date': '2017-12-11 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 059f7fc5719c7da6cbafe370971a8d70_85ce859fd6dc634de8d2f1e290444043 inserted successfully !!
# Successfully consumed record with key d2b091571da224a1b36412c18bc3bbfe_203096f03d82e0dffbc41ebc2e2bcfb7 and value {'order_id': '203096f03d82e0dffbc41ebc2e2bcfb7', 'customer_id': 'd2b091571da224a1b36412c18bc3bbfe', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-09-18 14:31:30', 'order_approved_at': '2017-09-19 04:04:09', 'order_delivered_carrier_date': '2017-10-06 17:50:03', 'order_delivered_customer_date': '2017-10-09 22:23:46', 'order_estimated_delivery_date': '2017-09-28 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record d2b091571da224a1b36412c18bc3bbfe_203096f03d82e0dffbc41ebc2e2bcfb7 inserted successfully !!
# Successfully consumed record with key 4fa1cd166fa598be6de80fa84eaade43_f848643eec1d69395095eb3840d2051e and value {'order_id': 'f848643eec1d69395095eb3840d2051e', 'customer_id': '4fa1cd166fa598be6de80fa84eaade43', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-03-15 08:52:40', 'order_approved_at': '2018-03-15 09:09:31', 'order_delivered_carrier_date': '2018-03-15 19:52:48', 'order_delivered_customer_date': '2018-03-19 18:08:32', 'order_estimated_delivery_date': '2018-03-29 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 4fa1cd166fa598be6de80fa84eaade43_f848643eec1d69395095eb3840d2051e inserted successfully !!
# Successfully consumed record with key a166da34890074091a942054b36e4265_95266dbfb7e20354baba07964dac78d5 and value {'order_id': '95266dbfb7e20354baba07964dac78d5', 'customer_id': 'a166da34890074091a942054b36e4265', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-01-08 07:55:29', 'order_approved_at': '2018-01-08 08:07:31', 'order_delivered_carrier_date': '2018-01-24 23:16:37', 'order_delivered_customer_date': '2018-01-26 17:32:38', 'order_estimated_delivery_date': '2018-02-21 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record a166da34890074091a942054b36e4265_95266dbfb7e20354baba07964dac78d5 inserted successfully !!
# Successfully consumed record with key 62b423aab58096ca514ba6aa06be2f98_f3e7c359154d965827355f39d6b1fdac and value {'order_id': 'f3e7c359154d965827355f39d6b1fdac', 'customer_id': '62b423aab58096ca514ba6aa06be2f98', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-08-09 11:44:40', 'order_approved_at': '2018-08-10 03:24:51', 'order_delivered_carrier_date': '2018-08-10 12:29:00', 'order_delivered_customer_date': '2018-08-13 18:24:27', 'order_estimated_delivery_date': '2018-08-17 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 62b423aab58096ca514ba6aa06be2f98_f3e7c359154d965827355f39d6b1fdac inserted successfully !!
# Successfully consumed record with key 3a874b4d4c4b6543206ff5d89287f0c3_fbf9ac61453ac646ce8ad9783d7d0af6 and value {'order_id': 'fbf9ac61453ac646ce8ad9783d7d0af6', 'customer_id': '3a874b4d4c4b6543206ff5d89287f0c3', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-02-20 23:46:53', 'order_approved_at': '2018-02-22 02:30:46', 'order_delivered_carrier_date': '2018-02-26 22:25:22', 'order_delivered_customer_date': '2018-03-21 22:03:54', 'order_estimated_delivery_date': '2018-03-12 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 3a874b4d4c4b6543206ff5d89287f0c3_fbf9ac61453ac646ce8ad9783d7d0af6 inserted successfully !!
# Successfully consumed record with key 761df82feda9778854c6dafdaeb567e4_ecab90c9933c58908d3d6add7c6f5ae3 and value {'order_id': 'ecab90c9933c58908d3d6add7c6f5ae3', 'customer_id': '761df82feda9778854c6dafdaeb567e4', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-02-25 13:50:30', 'order_approved_at': '2018-02-25 14:47:35', 'order_delivered_carrier_date': '2018-02-26 22:28:50', 'order_delivered_customer_date': '2018-03-27 23:29:14', 'order_estimated_delivery_date': '2018-04-13 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 761df82feda9778854c6dafdaeb567e4_ecab90c9933c58908d3d6add7c6f5ae3 inserted successfully !!
# Successfully consumed record with key 456dc10730fbdba34615447ea195d643_f70a0aff17df5a6cdd9a7196128bd354 and value {'order_id': 'f70a0aff17df5a6cdd9a7196128bd354', 'customer_id': '456dc10730fbdba34615447ea195d643', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-08-10 11:58:33', 'order_approved_at': '2017-08-12 02:45:24', 'order_delivered_carrier_date': '2017-08-17 15:35:07', 'order_delivered_customer_date': '2017-08-18 14:28:02', 'order_estimated_delivery_date': '2017-08-23 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 456dc10730fbdba34615447ea195d643_f70a0aff17df5a6cdd9a7196128bd354 inserted successfully !!
# Successfully consumed record with key 816f8653d5361cbf94e58c33f2502a5c_989225ba6d0ebd5873335f7e01de2ae7 and value {'order_id': '989225ba6d0ebd5873335f7e01de2ae7', 'customer_id': '816f8653d5361cbf94e58c33f2502a5c', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-12-12 13:56:04', 'order_approved_at': '2017-12-14 13:54:13', 'order_delivered_carrier_date': '2017-12-16 00:18:57', 'order_delivered_customer_date': '2018-01-03 18:03:36', 'order_estimated_delivery_date': '2018-01-08 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 816f8653d5361cbf94e58c33f2502a5c_989225ba6d0ebd5873335f7e01de2ae7 inserted successfully !!
# Successfully consumed record with key cf8ffeddf027932e51e4eae73b384059_b276e4f8c0fb86bd82fce576f21713e0 and value {'order_id': 'b276e4f8c0fb86bd82fce576f21713e0', 'customer_id': 'cf8ffeddf027932e51e4eae73b384059', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-07-29 23:34:51', 'order_approved_at': '2018-07-29 23:45:15', 'order_delivered_carrier_date': '2018-07-30 14:43:00', 'order_delivered_customer_date': '2018-07-31 22:48:50', 'order_estimated_delivery_date': '2018-08-06 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record cf8ffeddf027932e51e4eae73b384059_b276e4f8c0fb86bd82fce576f21713e0 inserted successfully !!
# Successfully consumed record with key f5458ddc3545711efa883dd7ae7c4497_60550084e6b4c0cb89a87df1f3e5ebd9 and value {'order_id': '60550084e6b4c0cb89a87df1f3e5ebd9', 'customer_id': 'f5458ddc3545711efa883dd7ae7c4497', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-02-21 18:15:12', 'order_approved_at': '2018-02-23 02:10:52', 'order_delivered_carrier_date': '2018-02-27 18:52:09', 'order_delivered_customer_date': '2018-03-13 23:58:43', 'order_estimated_delivery_date': '2018-03-29 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record f5458ddc3545711efa883dd7ae7c4497_60550084e6b4c0cb89a87df1f3e5ebd9 inserted successfully !!
# Successfully consumed record with key 3391c4bc11a817e7973e498b0b023158_7206b86ea789983f7a273ea7fa0bc2a8 and value {'order_id': '7206b86ea789983f7a273ea7fa0bc2a8', 'customer_id': '3391c4bc11a817e7973e498b0b023158', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-03-26 17:12:18', 'order_approved_at': '2018-03-26 17:28:27', 'order_delivered_carrier_date': '2018-03-28 17:22:53', 'order_delivered_customer_date': '2018-04-05 22:11:18', 'order_estimated_delivery_date': '2018-04-12 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 3391c4bc11a817e7973e498b0b023158_7206b86ea789983f7a273ea7fa0bc2a8 inserted successfully !!
# Successfully consumed record with key ddaff536587109b89777e0353215e150_1e7aff52cdbb2451ace09d0f848c3699 and value {'order_id': '1e7aff52cdbb2451ace09d0f848c3699', 'customer_id': 'ddaff536587109b89777e0353215e150', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-05-19 18:53:40', 'order_approved_at': '2017-05-19 19:05:17', 'order_delivered_carrier_date': '2017-05-22 10:16:07', 'order_delivered_customer_date': '2017-05-31 13:58:46', 'order_estimated_delivery_date': '2017-06-12 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record ddaff536587109b89777e0353215e150_1e7aff52cdbb2451ace09d0f848c3699 inserted successfully !!
# Successfully consumed record with key c7340080e394356141681bd4c9b8fe31_6ea2f835b4556291ffdc53fa0b3b95e8 and value {'order_id': '6ea2f835b4556291ffdc53fa0b3b95e8', 'customer_id': 'c7340080e394356141681bd4c9b8fe31', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-11-24 21:27:48', 'order_approved_at': '2017-11-25 00:21:09', 'order_delivered_carrier_date': '2017-12-13 21:14:05', 'order_delivered_customer_date': '2017-12-28 18:59:23', 'order_estimated_delivery_date': '2017-12-21 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record c7340080e394356141681bd4c9b8fe31_6ea2f835b4556291ffdc53fa0b3b95e8 inserted successfully !!
# Successfully consumed record with key 756fb9391752dad934e0fe3733378e57_d22e9fa5731b9e30e8b27afcdc2f8563 and value {'order_id': 'd22e9fa5731b9e30e8b27afcdc2f8563', 'customer_id': '756fb9391752dad934e0fe3733378e57', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-08-04 23:25:30', 'order_approved_at': '2018-08-04 23:35:13', 'order_delivered_carrier_date': '2018-08-06 15:03:00', 'order_delivered_customer_date': '2018-08-13 23:34:42', 'order_estimated_delivery_date': '2018-09-13 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 756fb9391752dad934e0fe3733378e57_d22e9fa5731b9e30e8b27afcdc2f8563 inserted successfully !!
# Successfully consumed record with key 12fd2740039676063a874b9567dfa651_25f4376934e13d3508486352e11a5db0 and value {'order_id': '25f4376934e13d3508486352e11a5db0', 'customer_id': '12fd2740039676063a874b9567dfa651', 'order_status': 'delivered', 'order_purchase_timestamp': '2018-05-17 16:59:11', 'order_approved_at': '2018-05-18 01:17:39', 'order_delivered_carrier_date': '2018-05-18 13:02:00', 'order_delivered_customer_date': '2018-05-21 15:22:11', 'order_estimated_delivery_date': '2018-05-25 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 12fd2740039676063a874b9567dfa651_25f4376934e13d3508486352e11a5db0 inserted successfully !!
# Successfully consumed record with key 7f2178c5d771e17f507d3c1637339298_2ce1ad82022c1ba30c2079502ac725aa and value {'order_id': '2ce1ad82022c1ba30c2079502ac725aa', 'customer_id': '7f2178c5d771e17f507d3c1637339298', 'order_status': 'delivered', 'order_purchase_timestamp': '2017-08-09 20:19:05', 'order_approved_at': '2017-08-11 04:15:29', 'order_delivered_carrier_date': '2017-08-11 17:52:32', 'order_delivered_customer_date': '2017-08-16 17:16:44', 'order_estimated_delivery_date': '2017-08-31 00:00:00', 'OrderHour': None, 'OrderDayOfWeek': None}
# Record 7f2178c5d771e17f507d3c1637339298_2ce1ad82022c1ba30c2079502ac725aa inserted successfully !!
